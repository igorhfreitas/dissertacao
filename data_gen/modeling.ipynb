# %%
import pandas as pd
import numpy as np
df=pd.read_csv("data_to_modeling.csv",sep='\t',index_col=0)
df=df.astype("float")
df
# Out:
#       depth     vc  rake_angle  clearance_angle  expected_cut_force      A  \
# 0       0.5  130.0       -10.0              5.0           64.304989  148.0
# 1       0.5  130.0        -7.0              5.0           64.304989  148.0
# 2       0.5  130.0        -4.0              5.0           64.304989  148.0
# 3       0.5  130.0        -1.0              5.0           64.304989  148.0
# 4       0.5  130.0         2.0              5.0           64.304989  148.0
# ...     ...    ...         ...              ...                 ...    ...
# 1373    0.5  180.0         5.0              5.0         1120.794897  553.0
# 1374    0.5  180.0         8.0              5.0         1120.794897  553.0
# 1375    0.5  180.0        11.0              5.0         1120.794897  553.0
# 1376    0.5  180.0        14.0              5.0         1120.794897  553.0
# 1377    0.5  205.0       -10.0              5.0         1251.382080  553.0
#
# ...

# %%
import plotly.express as px

fig = px.histogram(df, x="expected_cut_force", y="expected_cut_force")
fig.show()

# %%
list(df.drop("expected_cut_force",axis=1).columns)
# Out:
# ['depth',
#  'vc',
#  'rake_angle',
#  'clearance_angle',
#  'A',
#  'B',
#  'C',
#  'n',
#  'm',
#  'd1',
#  'd2',
#  'd3',
#  'd4',
#  'd5',
#  'densidade',
#  'young_modulus',
#  'poisson_coef']

# %%
from pycaret.regression import *
s = setup(df, target = 'expected_cut_force',fold_shuffle=True,numeric_features=list(df.drop("expected_cut_force",axis=1).columns),
imputation_type='iterative')
# Out:
# <style  type="text/css" >
# </style><table id="T_92cae_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_92cae_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_92cae_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_92cae_row0_col1" class="data row0 col1" >297</td>
#             </tr>
#             <tr>
#                         <th id="T_92cae_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_92cae_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_92cae_row1_col1" class="data row1 col1" >expected_cut_force</td>
#             </tr>
#             <tr>
# ...

# %%
import sklearn
sklearn.__version__
# Out:
# '1.2.0'

# %%
best = compare_models()

# %%
evaluate_model(best)

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'feature')
